# %%
import pandas as pd
import json

# %%
filename="ncov_data.json"
datastore={}
if filename:
    with open(filename, 'r') as f:
        datastore = json.load(f)

# %%
province_data1 = datastore["province"][0]["ProvinceDetail"]
date1 = '2020-02-02'
province_data2 = datastore["province"][0]["ProvinceDetail"]

#2020-02-02
pd_window1_2 = pd.DataFrame(province_data1)
#2020-01-29
pd_window1_1 = pd.DataFrame(datastore["province"][4]["ProvinceDetail"])
#2020-01-25
pd_window2_2 = pd.DataFrame(datastore["province"][8]["ProvinceDetail"])
#2020-01-21
pd_window2_1 = pd.DataFrame(datastore["province"][4]["ProvinceDetail"])
# Out:
#    Province  Confirmed  Dead  Cured  Severe  Critical  CloseContact   Obse  \
# 0       安徽省        408     0      7       0         4          8975      1
# 1       重庆市        300     2      7      23         6          8429   6471
# 2       广东省        683     0     14      57        20             1   2660
# 3       河北省        113     1      3      12         0          3796   2797
# 4       湖北省      11177   350    295    1223       478         32767  32767
# 5       江西省        391     0     18      34         0         10477   9303
# 6       山东省        246     0      6      16         1          7825   6299
# 7       山西省         66     0      2       5         0          1970   1539
# 8       天津市         48     0      1      15         3           301    276
# 9        西藏          1     0      0       0         0             0      0
# 10       澳门          8     0      0       0         0             1      1
# ...

# %%
window1_hubei['dead']
# Out:
# [{'Time': '2020-02-02',
#   'Province': ['安徽省',
#    '重庆市',
#    '广东省',
#    '河北省',
#    '湖北省',
#    '江西省',
#    '山东省',
#    '山西省',
#    '天津市',
#    '西藏',
#    '澳门',
#    '福建省',
#    '广西',
#    '黑龙江省',
#    '湖南省',
#    '上海市',
#    '四川省',
#    '香港',
#    '云南省',
#    '北京市',
#    '甘肃省',
#    '贵州省',
#    '河南省',
#    '江苏省',
#    '青海省',
#    '台湾省',
#    '新疆',
#    '浙江省',
#    '陕西省',
#    '海南省',
#    '吉林省',
#    '辽宁省',
#    '内蒙古',
#    '宁夏'],
#   'NcovNum': [408,
#    300,
#    683,
#    113,
#    11177,
#    391,
#    246,
#    66,
#    48,
#    1,
#    8,
#    179,
#    127,
#    118,
#    521,
#    193,
#    254,
#    15,
#    109,
#    212,
#    51,
#    46,
#    556,
#    271,
#    13,
#    10,
#    24,
#    724,
#    128,
#    70,
#    31,
#    70,
#    34,
#    31],
#   'ProvinceDetail': [{'Province': '安徽省',
#     'Confirmed': 408,
#     'Dead': 0,
#     'Cured': 7,
#     'Severe': 0,
#     'Critical': 4,
#     'CloseContact': 8975,
#     'Obse': 1,
#     'UnObse': 1},
# ...
